# %% [markdown]
# # [5.0] DESI DR1 x LSST DP2 Pilot Data

# %% [markdown]
# In this notebook, we will:
# - **move the catalog** at NERSC to provide a public endpoint of our DESI DR1 catalog
# - **crossmatch** the NERSC-hosted DESI DR1 catalog with the LSST DP2 Pilot Data at USDF
# - **save** the resulting catalog on USDF
# - discuss **performance and resource use** of the crossmatch

# %% [markdown]
# ## Pre-set up: move catalog to public NERSC dir
#
# In the shell, I ran:
# ```bash
# mv /global/cfs/cdirs/cosmo/users/olynn/desi-dr1-main-dark \
#    /global/cfs/cdirs/cosmo/www/users/olynn/desi-dr1-main-dark
# ```
#
# And to make it readable:
# ```bash
# chmod o+rX -R /global/cfs/cdirs/cosmo/www/users/olynn/
# ```
# But also:
# ```bash
# chmod o+rX /global/cfs/cdirs/cosmo/www/users/olynn
# ```

# %% [markdown]
# ## Set up

# %%
import lsdb
from dask.distributed import Client
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import lsdb
#       2 from dask.distributed import Client
#
# File ~/.local/lib/python3.11/site-packages/lsdb/__init__.py:2
#       1 from ._version import __version__
# ----> 2 from .catalog import Catalog, MarginCatalog
#       3 from .core.search import BoxSearch, ConeSearch, PolygonSearch
#       4 from .loaders.dataframe.from_dataframe import from_dataframe
#
# File ~/.local/lib/python3.11/site-packages/lsdb/catalog/__init__.py:1
# ----> 1 from .catalog import Catalog
#       2 from .map_catalog import MapCatalog
#       3 from .margin_catalog import MarginCatalog
#
# File ~/.local/lib/python3.11/site-packages/lsdb/catalog/catalog.py:6
#       3 from typing import Callable, List, Tuple, Type
#       5 import hats as hc
# ----> 6 import nested_dask as nd
#       7 import nested_pandas as npd
#       8 import pandas as pd
#
# File ~/.local/lib/python3.11/site-packages/nested_dask/__init__.py:1
# ----> 1 from . import backends, accessor  # noqa
#       2 from .core import NestedFrame  # noqa
#       3 from .io import read_parquet  # noqa
#
# File ~/.local/lib/python3.11/site-packages/nested_dask/backends.py:10
#       8 from dask.dataframe.extensions import make_array_nonempty
#       9 from dask.dataframe.utils import meta_nonempty
# ---> 10 from dask_expr import get_collection_type
#      11 from nested_pandas.series.ext_array import NestedExtensionArray
#      13 from .core import NestedFrame
#
# File ~/.local/lib/python3.11/site-packages/dask_expr/__init__.py:3
#       1 import dask.dataframe
# ----> 3 from dask_expr import _version, datasets
#       4 from dask_expr._collection import *
#       5 from dask_expr._dispatch import get_collection_type
#
# File ~/.local/lib/python3.11/site-packages/dask_expr/datasets.py:10
#       7 from dask.dataframe.utils import pyarrow_strings_enabled
#       8 from dask.typing import Key
# ---> 10 from dask_expr._collection import new_collection
#      11 from dask_expr._expr import ArrowStringConversion
#      12 from dask_expr.io import BlockwiseIO, PartitionsFiltered
#
# File ~/.local/lib/python3.11/site-packages/dask_expr/_collection.py:73
#      70 from pyarrow import fs as pa_fs
#      71 from tlz import first
# ---> 73 import dask_expr._backends  # noqa: F401
#      74 from dask_expr import _expr as expr
#      75 from dask_expr._backends import dataframe_creation_dispatch
#
# File ~/.local/lib/python3.11/site-packages/dask_expr/_backends.py:10
#       7 from dask.dataframe.dispatch import to_pandas_dispatch
#       9 from dask_expr._dispatch import get_collection_type
# ---> 10 from dask_expr._expr import ToBackend
#      12 try:
#      13     import sparse
#
# File ~/.local/lib/python3.11/site-packages/dask_expr/_expr.py:4114
#    4091     return meta
#    4094 from dask_expr._reductions import (
#    4095     All,
#    4096     Any,
#    (...)
#    4112     Var,
#    4113 )
# -> 4114 from dask_expr.io import IO, BlockwiseIO, FromArray, FromPandas
#    4115 from dask_expr.io._delayed import FromDelayed
#
# File ~/.local/lib/python3.11/site-packages/dask_expr/io/__init__.py:1
# ----> 1 from dask_expr.io.csv import *
#       2 from dask_expr.io.io import *
#       3 from dask_expr.io.parquet import *
#
# File ~/.local/lib/python3.11/site-packages/dask_expr/io/csv.py:9
#       7 from dask_expr._expr import Projection
#       8 from dask_expr._util import _convert_to_list
# ----> 9 from dask_expr.io.io import BlockwiseIO, PartitionsFiltered
#      12 class ReadCSV(PartitionsFiltered, BlockwiseIO):
#      13     _parameters = [
#      14         "filename",
#      15         "columns",
#    (...)
#      22         "dataframe_backend",
#      23     ]
#
# File ~/.local/lib/python3.11/site-packages/dask_expr/io/io.py:9
#       7 import numpy as np
#       8 import pyarrow as pa
# ----> 9 from dask._task_spec import List, Task
#      10 from dask.dataframe import methods
#      11 from dask.dataframe._pyarrow import to_pyarrow_string
#
# ImportError: cannot import name 'List' from 'dask._task_spec' (/sdf/home/o/olynn/.conda/envs/lsdb/lib/python3.11/site-packages/dask/_task_spec.py)

# %%
# Make a dask client

client = Client(
    n_workers=32,
    threads_per_worker=2,
    memory_limit="14GB",   # 32 × 14 = 448 GB, well within 487 GB
)

# %% [markdown]
# ## Load catalogs

# %% [markdown]
# ## Do crossmatch

# %% [markdown]
# ## Verify crossmatched catalog

# %% [markdown]
# ## Performance analysis
