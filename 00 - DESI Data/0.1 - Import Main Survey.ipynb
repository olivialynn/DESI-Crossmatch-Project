# %% [markdown]
# # 0.1 | DESI Data: Import Main Survey
#
# In the last notebook, we demonstrated a successful hats-import pipeline on two of the fits files in DESI DR1, main survey, dark program.
#
# In this notebook, we will scale this pipeline up to the entire main survey.

# %% [markdown]
# ## Planning
#
# - [ ] We will utilize Catalog Collections to organize the different programs in the main survey (light, dark, and backup).
#   - Since I don't really know how setting that up works, let's take some time to learn about it :)
# - [ ] We also need to make sure to set up our paths in a meaningul way, to target our cosmos user dir
# - [ ] Let's also make sure to be mindful in naming our catalog, instead of copy/pasting args from last nb abd forgetting
# - [ ] Additionally, make sure to adjust dask parrams after copy pasting
# - [ ] Also want to break the InputReader out into a Python file we can reference from this notebook
# - [ ] At this point, I should probably make a repo so I can be backing all this up...
